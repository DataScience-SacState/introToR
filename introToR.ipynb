# %%
xGrid <- c(10,8,13,9,11,14,6,4,12,7,5)

y1 <- c(8.04,6.95,7.58,8.81,8.33,9.96,7.24,4.26,10.84,4.82,5.68)
y2 <- c(9.14,8.14,8.74,8.77,9.26,8.10,6.13,3.10,9.13,7.26,4.74)
y3 <- c(7.46,6.77,12.74,7.11,7.81,8.84,6.08,5.39,8.15,6.42,5.73)
y4 <- c(6.58,5.76,7.71,8.84,8.47,7.04,5.25,12.50,5.56,7.91,6.89)

# %% [markdown]
# # Introduction to the R Programming Language

# %% [markdown]
# ## A language made for statisticians

# %% [markdown]
# ### The traditional hello world program

# %%
print("Hello World")

# %%
"Hello world"

# %% [markdown]
# ## Variables

# %%
x <- 4 -> y

# %%
x
y

# %%
x = 5

# %% [markdown]
# ## Lists

# %%
myList <- c(1,2,3,4,"five",pi)
myList
# Out:
# [1] "1"                "2"                "3"                "4"
# [5] "five"             "3.14159265358979"

# %%
1:6
# Out:
# [1] 1 2 3 4 5 6

# %% [markdown]
# ### Subsets

# %%
myList[0]
myList[1]
myList[1:3]
myList[-1:-3]
# Out:
# character(0)
# [1] "1"
# [1] "1" "2" "3"
# [1] "4"                "five"             "3.14159265358979"

# %% [markdown]
# ## \# is the symbol for comments

# %% [markdown]
# ## Functions

# %%
seq(1,6)
# Out:
# [1] 1 2 3 4 5 6

# %%
seq(1,6,2)
# Out:
# [1] 1 3 5

# %%
seq(by=2,from=1,to=6)
# Out:
# [1] 1 3 5

# %% [markdown]
# ### Manuals

# %%
?seq
# Out:
# seq                    package:base                    R Documentation
#
# n
#
# n:
#
#      Generate regular sequences.  ‘seq’ is a standard generic with a
#      default method.  ‘seq.int’ is a primitive which can be much faster
#      but has a few restrictions.  ‘seq_along’ and ‘seq_len’ are very
#      fast primitives for two common cases.
#
# e:
#
#      seq(...)
#
#      ## Default S3 method:
#      seq(from = 1, to = 1, by = ((to - from)/(length.out - 1)),
#          length.out = NULL, along.with = NULL, ...)
#
#      seq.int(from, to, by, length.out, along.with, ...)
#
#      seq_along(along.with)
#      seq_len(length.out)
#
# s:
#
#      ...: arguments passed to or from methods.
#
# from, to: the starting and (maximal) end values of the sequence.  Of
#           length ‘1’ unless just ‘from’ is supplied as an unnamed
#           argument.
#
#       by: number: increment of the sequence.
#
# length.out: desired length of the sequence.  A non-negative number,
# ...

# %%
?? sequence

# %% [markdown]
# ## Making your own function

# %%
myFun <- function(x){
    2^2.5
}

# %%
myFun(2)
# Out:
# [1] 5.656854

# %% [markdown]
# #### There is no return keyword.

# %% [markdown]
# ## If statements and logical operators

# %%
if(TRUE)
    5
# Out:
# [1] 5

# %%
if(FALSE){
    5
    }else if(TRUE)
        3
# Out:
# [1] 3

# %%
x = 3
y = pi
x < y
x <= y
x >= y
x == y
x !=y
# Out:
# [1] TRUE
# [1] TRUE
# [1] FALSE
# [1] FALSE
# [1] TRUE

# %%
!TRUE
TRUE & TRUE
TRUE | FALSE
!(TRUE | FALSE)
# Out:
# [1] FALSE
# [1] TRUE
# [1] TRUE
# [1] FALSE

# %% [markdown]
# ## Loops

# %% [markdown]
# ### For loop

# %%
total = 0
for(i in 1:6){
    total = total + i
}
total
# Out:
# [1] 21

# %% [markdown]
# ##### How would it change if  I did this?

# %%
total = 0
for(i in 1:6){
    total = total + i
    total
}

# %% [markdown]
# ### While loop

# %%
x = c(4,3,7,8)

i = 1
while(i < length(x)){
    if(x[i]==3){
        print("3 is in the list")
    }
    i = i + 1
}
# Out:
# [1] "3 is in the list"

# %% [markdown]
# ## Graphics

# %% [markdown]
# ### I have 3 lists that all have the same length and regression analysis, what else do i know?

# %% [markdown]
# ### Imagine these 3 lists, are the output of function given this list as the input.

# %%
xGrid
# Out:
#  [1] 10  8 13  9 11 14  6  4 12  7  5

# %%
length(y1);length(y2);length(y3) #semicolon to do 4 commands on the same line
mean(y1); mean(y2); mean(y3)
# Out:
# [1] 11
# [1] 11
# [1] 11
# [1] 7.500909
# [1] 7.500909
# [1] 7.5

# %% [markdown]
# ### This is the importance of statistical graphs.

# %%
plot(xGrid,y1)
plot(xGrid,y2)
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %%
plot(xGrid,y3)
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %% [markdown]
# ### Lets look at the plot function and some of its other parameters.

# %%
?plot
# Out:
# plot                 package:graphics                  R Documentation
#
# g
#
# n:
#
#      Generic function for plotting of R objects.  For more details
#      about the graphical parameter arguments, see ‘par’.
#
#      For simple scatter plots, ‘plot.default’ will be used.  However,
#      there are ‘plot’ methods for many R objects, including
#      ‘function’s, ‘data.frame’s, ‘density’ objects, etc.  Use
#      ‘methods(plot)’ and the documentation for these.
#
# e:
#
#      plot(x, y, ...)
#
# s:
#
#        x: the coordinates of points in the plot. Alternatively, a
#           single plotting structure, function or _any R object with a
#           ‘plot’ method_ can be provided.
#
#        y: the y coordinates of points in the plot, _optional_ if ‘x’ is
#           an appropriate structure.
#
#      ...: Arguments to be passed to methods, such as graphical
#           parameters (see ‘par’).  Many methods will accept the
#           following arguments:
#
# ...

# %%
?par
# Out:
# par                  package:graphics                  R Documentation
#
# s
#
# n:
#
#      ‘par’ can be used to set or query graphical parameters.
#      Parameters can be set by specifying them as arguments to ‘par’ in
#      ‘tag = value’ form, or by passing them as a list of tagged values.
#
# e:
#
#      par(..., no.readonly = FALSE)
#
#      <highlevel plot> (..., <tag> = <value>)
#
# s:
#
#      ...: arguments in ‘tag = value’ form, or a list of tagged values.
#           The tags must come from the names of graphical parameters
#           described in the ‘Graphical Parameters’ section.
#
# no.readonly: logical; if ‘TRUE’ and there are no other arguments, only
#           parameters are returned which can be set by a subsequent
#           ‘par()’ call _on the same device_.
#
# s:
#
#      Each device has its own set of graphical parameters.  If the
#      current device is the null device, ‘par’ will open a new device
# ...

# %%
?pch
# Out:
# points                package:graphics                 R Documentation
#
# t
#
# n:
#
#      ‘points’ is a generic function to draw a sequence of points at the
#      specified coordinates.  The specified character(s) are plotted,
#      centered at the coordinates.
#
# e:
#
#      points(x, ...)
#
#      ## Default S3 method:
#      points(x, y = NULL, type = "p", ...)
#
# s:
#
#     x, y: coordinate vectors of points to plot.
#
#     type: character indicating the type of plotting; actually any of
#           the ‘type’s as in ‘plot.default’.
#
#      ...: Further graphical parameters may also be supplied as
#           arguments.  See ‘Details’.
#
# s:
#
#      The coordinates can be passed in a plotting structure (a list with
#      ‘x’ and ‘y’ components), a two-column matrix, a time series, ....
#      See ‘xy.coords’.  If supplied separately, they must be of the same
#      length.
#
#      Graphical parameters commonly used are
#
# ...

# %%
methods(plot)
# Out:
#  [1] plot.acf*           plot.data.frame*    plot.decomposed.ts*
#  [4] plot.default        plot.dendrogram*    plot.density*
#  [7] plot.ecdf           plot.factor*        plot.formula*
# [10] plot.function       plot.hclust*        plot.histogram*
# [13] plot.HoltWinters*   plot.isoreg*        plot.lm*
# [16] plot.medpolish*     plot.mlm*           plot.ppr*
# [19] plot.prcomp*        plot.princomp*      plot.profile.nls*
# [22] plot.raster*        plot.spec*          plot.stepfun
# [25] plot.stl*           plot.table*         plot.ts
# [28] plot.tskernel*      plot.TukeyHSD*
# see '?methods' for accessing help and source code

# %%
?plot.function
# Out:
# curve                 package:graphics                 R Documentation
#
# s
#
# n:
#
#      Draws a curve corresponding to a function over the interval
#      ‘[from, to]’. ‘curve’ can plot also an expression in the variable
#      ‘xname’, default ‘x’.
#
# e:
#
#      curve(expr, from = NULL, to = NULL, n = 101, add = FALSE,
#            type = "l", xname = "x", xlab = xname, ylab = NULL,
#            log = NULL, xlim = NULL, ...)
#
#      ## S3 method for class 'function'
#      plot(x, y = 0, to = 1, from = y, xlim = NULL, ylab = NULL, ...)
#
# s:
#
#     expr: The name of a function, or a call or an expression written as
#           a function of ‘x’ which will evaluate to an object of the
#           same length as ‘x’.
#
#        x: a ‘vectorizing’ numeric R function.
#
#        y: alias for ‘from’ for compatibility with ‘plot’
#
# from, to: the range over which the function will be plotted.
#
#        n: integer; the number of x values at which to evaluate.
#
# ...

# %%
plot.function(exp,from=1, to = 15) #exp(x) is e^x
#an example of r's functional programming capabilities.
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %% [markdown]
# # I'm going to move over to rstudio to for a few more examples
